# %% [markdown]
# <a href="https://colab.research.google.com/github/segio-165/MY-ACHIEVEMENT-2026/blob/main/eval_runs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/EverlynAsiko/lm-evaluation-harness.git
# Out:
# Cloning into 'lm-evaluation-harness'...
# remote: Enumerating objects: 43614, done.
# remote: Total 43614 (delta 0), reused 0 (delta 0), pack-reused 43614 (from 1)
# Receiving objects: 100% (43614/43614), 27.21 MiB | 14.99 MiB/s, done.
# Resolving deltas: 100% (29043/29043), done.

# %%
# !cd lm-evaluation-harness; pip install -e .
# Out:
# Obtaining file:///content/lm-evaluation-harness
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 6.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 kB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 13.0 MB/s eta 0:00:00
# ...
#   Building editable for lm_eval (pyproject.toml) ... done
# ...

# %% [markdown]
# # Inkuba, MAsakhaNER

# %%
# !huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `hf auth whoami` to get more information or `hf auth logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# ...

# %%
# !pip install "datasets<=3.6.0"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 38.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %%
# !lm_eval --model hf \
    --model_args pretrained=lelapa/InkubaLM-0.4B \
    --tasks  masakhane/masakhapos\
    --device cuda:0 \
    --batch_size 4 \
    --output_path ./results \
    --log_samples
# Out:
# /bin/bash: line 1: lm_eval: command not found

# %%
# !lm_eval --model hf \
    --model_args pretrained=masakhane/masakhapos \
    --tasks hellaswag\
    --device cuda:0 \
    --batch_size 4 \
    --output_path ./results \
    --log_samples
# Out:
# /bin/bash: line 1: lm_eval: command not found

# %%
# !lm-eval ls tasks
# Out:
# /bin/bash: line 1: lm-eval: command not found

# %%
# !lm_eval --tasks list
# Out:
# Streaming output truncated to the last 5000 lines.
# |include_base_44_russian_few_shot_en_applied_science                                   |lm_eval/tasks/include/few_shot_en/Russian/include_base_44_russian_applied_science.yaml                                                                          |multiple_choice      |
# |include_base_44_russian_few_shot_en_arts_humanities                                   |lm_eval/tasks/include/few_shot_en/Russian/include_base_44_russian_arts_humanities.yaml                                                                          |multiple_choice      |
# |include_base_44_russian_few_shot_en_business_commerce                                 |lm_eval/tasks/include/few_shot_en/Russian/include_base_44_russian_business_commerce.yaml                                                                        |multiple_choice      |
# ...
